# %% [markdown]
# # Data Visualization - Bar ChartsCreating bar chart visualizations using Matplotlib and Pandas for data analysis.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('TASK 2..csv')
df

# %%
plt.bar(x=df['FORUM'],height=df['VALUES'],color='red')
