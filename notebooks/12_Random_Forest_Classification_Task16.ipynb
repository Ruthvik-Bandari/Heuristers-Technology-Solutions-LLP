# %% [markdown]
# # Random Forest Classification - Task 16Final classification task demonstrating end-to-end ML pipeline.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv('TASK 16.csv')
data

# %%
data.head()

# %%
data.tail()

# %%
data.shape

# %%
data.info()

# %%
data.isnull()

# %%
data.isnull().sum()

# %%
from sklearn.model_selection import train_test_split
x=data.iloc[:,data.columns!='Outcome']
y=data.iloc[:,data.columns=='Outcome']

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.5)
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()
model.fit(xtrain,ytrain.values.ravel())

# %%
output=model.predict(xtest)
output

# %%
from sklearn.metrics import accuracy_score
acc=accuracy_score(output,ytest)
print("The accuracy score is:",acc)
